# %%
import numpy as np
import pandas as pd
import string
import re

# %%
with open('business_card_data_vie_clean.txt', mode='r', encoding='utf8',errors='ignore') as f:
    text = f.read()

# %%
data = list(map(lambda x:x.split('\t'), text.split('\n')))

# %%
df = pd.DataFrame(data[1:],columns=data[0])

# %%
df.head()
# Out:
#          id   text    tag
# 0  001.jpeg   Huấn  B-DES
# 1  001.jpeg  luyện  I-DES
# 2  001.jpeg   viên  I-DES
# 3  001.jpeg    Thể  I-DES
# 4  001.jpeg   hình  I-DES

# %%
whitespace = string.whitespace
punctuation = "!#$%&\'()*+:;<=>?[\\]^`{|}~"
tableWhitespace = str.maketrans('','',whitespace)
tablePunctuation = str.maketrans('','',punctuation)
def cleanText(txt):
    text = str(txt)
    text = text.lower()
    removewhitespace = text.translate(tableWhitespace)
    removepunctuation = removewhitespace.translate(tablePunctuation)
    
    return str(removepunctuation)

# %%
df['text'] = df['text'].apply(cleanText)

# %%
dataClean = df.query("text != ''")
dataClean.dropna(inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9320\111782460.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataClean.dropna(inplace=True)

# %%
group = dataClean.groupby(by='id')

# %%
cards = group.groups.keys()

# %%
allCardsData = []
for card in cards:
    cardData = []
    grouparray = group.get_group(card)[['text','tag']].values
    content = ''
    annotations = {'entities':[]}
    start = 0
    end = 0
    for text, label in grouparray:
        text = str(text)
        stringLength = len(text) + 1

        start = end
        end = start + stringLength

        if label != 'O' or label != 'O':
            annot = (start,end-1,label)
            annotations['entities'].append(annot)

        content = content + text + ' '
        
        
    cardData = (content,annotations)
    allCardsData.append(cardData)

# %%
allCardsData
# Out:
# [('Huấn luyện viên Thể hình Có nhân được Chứng nhận Quét để tập thử miễn phí ',
#   {'entities': [(0, 4, 'B-DES'),
#     (5, 10, 'I-DES'),
#     (11, 15, 'I-DES'),
#     (16, 19, 'I-DES'),
#     (20, 24, 'I-DES')]}),
#  ('Mai Hương QUẢN LÝ 123 Trần Nhật Duật, Hà Nội www.trongwebhay.vn 912 345 67890 ',
#   {'entities': [(0, 3, 'B-NAME'),
#     (4, 9, 'I-NAME'),
#     (10, 14, 'B-DES'),
#     (15, 17, 'I-DES'),
#     (18, 21, 'B-ADDRESS'),
#     (22, 26, 'I-ADDRESS'),
#     (27, 31, 'I-ADDRESS'),
#     (32, 37, 'I-ADDRESS'),
#     (38, 40, 'I-ADDRESS'),
#     (41, 44, 'I-ADDRESS'),
#     (45, 63, 'B-WEB'),
#     (64, 67, 'B-PHONE'),
#     (68, 71, 'I-PHONE'),
#     (72, 77, 'I-PHONE')]}),
#  ('Huỳnh Minh Nhân Nhiếp ảnh gia chuyên nghiệp Địa chỉ email xinchao@trangwebhay.vn Mạng xã hội @trangwebhay Điện thoại 84 912 345 678 ',
#   {'entities': [(0, 5, 'B-NAME'),
#     (6, 10, 'I-NAME'),
#     (11, 15, 'I-NAME'),
#     (16, 21, 'B-DES'),
#     (22, 25, 'I-DES'),
#     (26, 29, 'I-DES'),
# ...

# %%
import random

# %%
random.shuffle(allCardsData)

# %%
print(len(allCardsData))
# Out:
# 267

# %%
split_index = int(len(allCardsData) * 0.8)
TrainData = allCardsData[:split_index]
TestData = allCardsData[split_index:]

# %%
import pickle

# %%
pickle.dump(TrainData,open('./data/TrainData_Vie.pickle', mode='wb'))
pickle.dump(TestData,open('./data/TestData_Vie.pickle', mode='wb'))
